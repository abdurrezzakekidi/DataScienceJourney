# %% [markdown]
# ### Veriye İlk Bakış

# %% [markdown]
# #### Veri Seti Hikayesi ve Yapısının İncelenmesi

# %% [markdown]
# #### Keşifçi Veri Analizi Nedir? Betimsel istatistik , veri görselleştirme teknikleri ve iş çıktısı heddefiyle veri üzerinde çalışmaktır.

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df = planets.copy()

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
# veri setinin yapısal bilgilerl
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df.dtypes
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %%
import pandas as pd
df.method = pd.Categorical(df.method)

# %%
df.dtypes
# Out:
# method            category
# number               int64
# orbital_period     float64
# mass               float64
# distance           float64
# year                 int64
# dtype: object

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# #### Veri Setinin Betimlenmesi

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
df= planets.copy()

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.shape
# Out:
# (1035, 6)

# %%
df.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
"""
.T yani (transpozunu) alarak gözlemlersek  bu bize daha güzel bir
bilgi sonucaktır bu eksik gözlemleri gözardı eder ve kategorik
değişkenleri dışarda bırakır.
"""
df.describe().T
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %%
df.describe(include = "all").T
# Out:
#                  count unique              top freq         mean  \
# method            1035     10  Radial Velocity  553          NaN
# number          1035.0    NaN              NaN  NaN     1.785507
# orbital_period   992.0    NaN              NaN  NaN  2002.917596
# mass             513.0    NaN              NaN  NaN     2.638161
# distance         808.0    NaN              NaN  NaN   264.069282
# year            1035.0    NaN              NaN  NaN  2009.070531
#
#                          std       min      25%      50%      75%       max
# method                   NaN       NaN      NaN      NaN      NaN       NaN
# number              1.240976       1.0      1.0      1.0      2.0       7.0
# orbital_period  26014.728304  0.090706  5.44254  39.9795  526.005  730000.0
# mass                3.818617    0.0036    0.229     1.26     3.04      25.0
# distance          733.116493      1.35    32.56    55.25    178.5    8500.0
# ...

# %% [markdown]
# #### Eksik değerlerin İncelenmesi

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
df = planets.copy()
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
# hiç eksik gözlem  (değer) var mı?
df.isnull().values.any()
# Out:
# True

# %%
# hangi  değişken kaçar tane var ( eksik değer)
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
"""
şimdi hızlı bir çözüm olarak 2 şey işleyeceğiz 1. veri seti içerisinde yer alan
bütün any'lere(boş değer) 0 değerini basabiliriz orda eksiklik gözükmesin bazı işlemler problem
yaratmasın diye düşünerek bütün eksik değerlerin yerine  0 değerini basarız...
bunun yerine ortalama değeri koyabiliriz .(fakat eksik değer çok hassas bir konudur burda 
eksiklik demek bir çok anlama gelebilir)
"""
df["orbital_period"].fillna(0, inplace = True)
df["mass"].fillna(df.mass.mean(),inplace = True)
# tüm eksik değerlerin yerine  ortalama değerleri atanmış olacak
#df.fillna(df.mean(), inplace = True)
# Out:
# C:\Users\Abdurezzak Ekidi\AppData\Local\Temp\ipykernel_7392\3488865802.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["orbital_period"].fillna(0, inplace = True)
# C:\Users\Abdurezzak Ekidi\AppData\Local\Temp\ipykernel_7392\3488865802.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period      0
# mass                0
# distance          227
# year                0
# dtype: int64

# %%
df = planets.copy()
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %% [markdown]
# ### Kategorik Değişken Özetleri

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
df = planets.copy()
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# #### Sadece Kategorik Değişkenler ve Özetleri

# %%
kat_df = df.select_dtypes(include = ["object"])

#yukardaki satırda veri setinden object türünde olan verileri seç ama eğer object'ten category'y 
#dönüştürme işlemi yaptıysak [category] diyeceğiz

# %%
kat_df.head(6)
# Out:
#             method
# 0  Radial Velocity
# 1  Radial Velocity
# 2  Radial Velocity
# 3  Radial Velocity
# 4  Radial Velocity
# 5  Radial Velocity

# %% [markdown]
# #### Kategorik Değişkenin Sınıflarına ve Sınıf Sayısına Erişmek

# %%
kat_df .method.unique()
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Transit Timing Variations',
#        'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#        'Pulsation Timing Variations'], dtype=object)

# %%
kat_df["method"].value_counts().count()
# sınıf sayısı
# Out:
# 10

# %% [markdown]
# #### Kategorik Değişkenin Sınıflarının Frekansalrına Erişmek

# %%
kat_df["method"].value_counts()
# Out:
# method
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: count, dtype: int64

# %%
df["method"].value_counts().plot.barh();

# %% [markdown]
# #### Sürekli Değişken Özetleri

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
df = planets.copy()
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df_num = df.select_dtypes(include = ["float64", "int64"])
df_num.head()
# Out:
#    number  orbital_period   mass  distance  year
# 0       1         269.300   7.10     77.40  2006
# 1       1         874.774   2.21     56.95  2008
# 2       1         763.000   2.60     19.84  2011
# 3       1         326.030  19.40    110.62  2007
# 4       1         516.220  10.50    119.47  2009

# %%
df_num.describe().T
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %%
df_num[["distance"]].describe().T
# Out:
#           count        mean         std   min    25%    50%    75%     max
# distance  808.0  264.069282  733.116493  1.35  32.56  55.25  178.5  8500.0

# %%
print("Ortalama:" + str(df_num["distance"].mean()))
print("Dolu Gözlem Sayısı:" + str(df_num["distance"].count()))
print("Max Değer:" + str(df_num["distance"].max()))
print("Min Değer:" + str(df_num["distance"].min()))
print("Medyan :" + str(df_num["distance"].median()))
print("Standart Sapma:" + str(df_num["distance"].std()))
# Out:
# Ortalama:264.06928217821786
# Dolu Gözlem Sayısı:808
# Max Değer:8500.0
# Min Değer:1.35
# Medyan :55.25
# Standart Sapma:733.1164929404422

# %% [markdown]
# ### Dağılım Grafikleri
# ##### Barplot

# %% [markdown]
# ## Veri Seti Hikayesi
# #### (Pırlantalarla ilgili bilgi sunan bir veri setidir.)
# - **price:** dolar cinsinde fiyat (326–18,823)
# - **carat:** ağırlık (0.2–5.01)
# - **cut:** kalite (Fair, Good, Very Good, Premium, Ideal)
# - **color:** renk (from J (worst) to D (best))
# - **clarity:** temizliği, berraklığı (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# - **x:** length in mm (0–10.74)
# - **y:** width in mm (0–58.9)
# - **z:** depth in mm (0–31.8)
# - **depth:** toplam derinlik yüzdesi = z / mean(x, y) = 2 * z / (x + y) (43–79)
# - **table:** elmasın en geniş noktasına göre genişliği (43–95)

# %%
import seaborn as sns
diamonds = sns.load_dataset("diamonds")
df = diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ##### Veri Setine Hızlı Bakış

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
df["color"].value_counts()
# Out:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %%
# ordinal tanımlama  eski kod çalışmaz 
from pandas.api.types import is_categorical_dtype

# %%
#df.cut.astype(is_categorical_dtype ( ordered = True))

# %%
import pandas as pd

# %%
df.cut.head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
 #Kategorik veri türüne dönüştürmek ve sıralı hale getirmek
cut_kategoriler =['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
df['cut'] = pd.Categorical(df['cut'], categories= cut_kategoriler, ordered=True)

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df.cut.head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Fair' < 'Good' < 'Very Good' < 'Premium' < 'Ideal']

# %% [markdown]
# ### barblot

# %%
df["cut"].value_counts().plot.barh().set_title("Cut Değişkeninin Sınıf Frekansları ");

# %%
# pandas ile
(df["cut"]
 .value_counts()
 .plot.barh()
 .set_title("Cut Değişkeninin Sınıf Frekansları"));

# %%
#saborn ile
sns.barplot(x = "cut", y = df.cut.index ,palette='viridis', data = df);
# Out:
# C:\Users\Abdurezzak Ekidi\AppData\Local\Temp\ipykernel_7392\2475795938.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "cut", y = df.cut.index ,palette='viridis', data = df);

# %% [markdown]
# ### Çaprazlamalar
# #### veri seti içerisinde yer alan değişkenlerin birlikte değelendirilmesi.

# %%
import seaborn as sns
import pandas as pd

diamonds = sns.load_dataset("diamonds")
df = diamonds.copy()
cut_kategoriler =['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
df['cut'] = pd.Categorical(df['cut'], categories= cut_kategoriler, ordered=True)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# catplot categorik değişkenleri görselleştirmek için kullanılan bir fonksiyon
"""custom_palette = {
    "Ideal": "purple",     # Mor
    "Premium": "red",     # Mavi
    "Very Good": "green",  # Yeşil
    "Good": "orange",      # Turuncu
    "Fair": "blue"          # Kırmızı
}
sns.catplot(x = "cut", y = "price", data = df, palette = custom_palette);
eski kullanim!!!!!!!!!!!!!!!!!!!
"""

(sns.stripplot(
    x = "cut",
    y = "price",
    hue='cut',
    data = df,
    palette = custom_palette));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[115], line 18
#       1 # catplot categorik değişkenleri görselleştirmek için kullanılan bir fonksiyon
#       2 """custom_palette = {
#       3     "Ideal": "purple",     # Mor
#       4     "Premium": "red",     # Mavi
#    (...)
#      10 eski kullanim!!!!!!!!!!!!!!!!!!!
#      11 """
#      13 (sns.stripplot(
#      14     x = "cut",
#      15     y = "price",
#      16     hue='cut',
#      17     data = df,
# ---> 18     palette = custom_palette))
#
# NameError: name 'custom_palette' is not defined

# %%
(sns.barplot
 (x = "cut",
  y = "price",
  hue = "color",
  data = df));
plt.title("caprazlama");

# %%
# yukardaki grafiği doğruluyoruz 
#df.groupby(["cut", "color"])["price"].mean() eski kullanim
df.groupby(["cut", "color"], observed=False)["price"].mean()

# %% [markdown]
# ### Histogram ve Yoğunluk
# ##### sayısal değişkenler için kullanılan sayısal değişkenlerin dağılımını ifade etmek için kullanılan ver görselleştirme teknikleridir.

# %%
import  seaborn as sns
import matplotlib.pyplot as plt
diamonds = sns.load_dataset("diamonds")
df = diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# distplot dağılım göselleştirmek için kullanılan bir fonksiyon (df.price ) bana
#görselleştirmek istediğin değişkeni ifade et diyor. kde = False  argümanını False yapıyoruz
# bu yıoğunluk fonksiyonunda  grafiğin üzerinde koyulup koyulmamasıyla  ilgili  bir ayarlama

#sns.distplot(df.price, kde = False).set_title("histogram"); eski kullanim
sns.histplot(df["price"],
            kde = False,
             color = 'RED'
            );
plt.title("histogram")
# Out:
# Text(0.5, 1.0, 'histogram')

# %%
#sns.distplot(df.price, bins = 100, kde = False); eski kullanim

sns.histplot(df['price'],
             kde=False,
            bins =200);

# %%
df["price"].describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
# Histogram'ın üzerinde yoğunluk grafiği
#sns.distplot(df.price);  eski kullanim
sns.histplot(df['price'], kde=True);

# %%
# eğer sadece yoğunluk grafiğini görmek istersek
sns.kdeplot(df['price'], fill = False);

# %%
# yoğunluk grafiğin altını doldurak ta kullanabiliriz.
# shade argumani fill argumai ile degismitit (fill yeni kullanim)
sns.kdeplot(df.price, fill = True);

# %% [markdown]
# ### Histogram ve Yoğunluk İçin Çaprazlamalar

# %%
import seaborn as sns
diamonds = sns.load_dataset('diamonds')
df = diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.kdeplot(df.price, fill = True );

# %%
"""
FacetGrid  graikler üzerinde eklenen boyutları bölerek göstermek için kullanılır.
hue boyut ekleme argümanı 
height yükseklik
oluşturulacak olan grafiğin  x veye y ekseninini ayarlıyabiliyoruz xlim

bir kdeplot grafiği oluşturacağız pric'e göre fakat bunu  FacetGrid fonksiyonunu kullanarak 
tüm cut sınıflarıyla map'lemiş  olucağız.
"""
(sns
 .FacetGrid(df,
              hue = "cut",
              height = 5,
              xlim = (0,10000))
 .map(sns.kdeplot, "price", fill = True)
 # Aciklama  ekleme
 .add_legend()
);

# %% [markdown]
# #### Machine Learning (Makine Öğrenmesi) de amacımız  hedeflediğimiz bağımlı değişkende var olan bilgiyi (değişimi ) farklı değişkenlerce açıklamaya çalışmaktır. Bu değişimi farklı değişkenlerce  açıklamaya çalışmak amacının en büyük hedefi veri setinin içerisndeki hedef değişken hedefiyle değişkenliklerin bulunmaya  çalışmasıdır.

# %%
# kind türü ifade etmek için kullanılyor .  
"""
cut'ın içinde ideal sınıfı üzerinden düşünecek olursak öncelikle bu sınıf'ın içinde color 
değişkeni'nin kategorilerinin dağılyor olması ( yani bir birlerinden farklı seviyelerde gözlemleniyor olması)
color aracığıyla cut değişkeni sınıfları kesişiminde bir bilgi taşındığı(farklı bilgi taşındığı) 
anlamına  geliyor. ama ideal de bulunan turuncu(E) ve mavi(D) sınıfı için çokta geçerli değil.
"""
sns.catplot(x = "cut", y = "price", hue = "color", kind = "point", data = df);

# %% [markdown]
# ### Boxplot

# %% [markdown]
# ## Veri Seti Hikayesi
#
# - **total_bill:** yemeğin toplam fiyatı (bahşiş ve vergi dahil)
# - **tip:** bahşiş
# - **sex:** ücreti ödeyen kişinin cinsiyeti (0=male, 1=female)
# - **smoker:** grupta sigara içen var mı? (0=No, 1=Yes)
# - **day:** gün (3=Thur, 4=Fri, 5=Sat, 6=Sun)
# - **time:** ne zaman? (0=Day, 1=Night)
# - **size:** grupta kaç kişi var?

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df["time"].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %% [markdown]
# ### Boxplot(Kutu grafiği)
# ##### boxplot bize kartiller aracığıyla  çok değerli bilgi sunan bir görselleştirme tekniğidir yapılacak olan çaprazlamalar ile bize çok değerli bilgiler sunar.

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x = df ["total_bill"]);

# %%
# dikey 
sns.boxplot(y = df ["total_bill"]);

# %% [markdown]
# ### Çaprazlamalar(boxplot)

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
#Hangi günler faha fazla kazanıyoruz
sns.boxplot(x = "day", y = "total_bill",color = "green", data = df);

# %%
# sabah mı akşam mı  daha çok kazanıyoruz?
sns.boxplot(x = "time", y = "total_bill", data = df);

# %%
# kişi sayısı kazanç
sns.boxplot(x = "size", y = "total_bill", data = df);

# %%
sns.boxplot(x = "day", y = "total_bill", hue = "sex", data = df);

# %% [markdown]
# ### Violin
# #### boxplot'a benzerdir biraz daha dağılım anlamında  bilgi sunar

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(y = "total_bill", kind ="violin", data = df)

# %% [markdown]
# #### Violin Grafik Çaprazlamalar

# %%
sns.catplot(x = "day" , y = "total_bill", kind = "violin", data = df);

# %%
sns.catplot(x = "day", y = "total_bill", hue = "sex", kind = "violin", data  = df);

# %% [markdown]
# ## Korelasyon Grafikleri
# #### korelasyon değişkenler arasındaki ilişkiyi ifade eden istatistiksel bir terimdir

# %% [markdown]
# ## Scatterplot(saçılıım grafiği)
# #### Scatterplot sayısal değişkenler arasındaki ilişkiyi gösterir.
#
# - **total_bill:** yemeğin toplam fiyatı (bahşiş ve vergi dahil)
# - **tip:** bahşiş
# - **sex:** ücreti ödeyen kişinin cinsiyeti (0=male, 1=female)
# - **smoker:** grupta sigara içen var mı? (0=No, 1=Yes)
# - **day:** gün (3=Thur, 4=Fri, 5=Sat, 6=Sun)
# - **time:** ne zaman? (0=Day, 1=Night)
# - **size:** grupta kaç kişi var?

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
(sns.scatterplot(x = "total_bill", y = "tip", data = df)
.set_title("ödenen hesap arttıkça bahşiş artıyor"));

# %% [markdown]
# ### Korelasyon Çaprazlamalar

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "time", data = df);

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "time",style = "time", data = df);

# %%
# kategorik degiskenleri boyut olarak ekledik (style argumani )
sns.scatterplot(x = "total_bill", y = "tip", hue = "day", style = "day", data = df);

# %%
# surekli degiskenleri boyut olarak ekledik( size argumani)
sns.scatterplot(x = "total_bill", y = "tip",  size = "size", data = df);

# %%
# sürekli(sayısal) değişkeni bir boyut olarak eklemek istersek
sns.scatterplot(x = "total_bill", y = "tip", hue = "size",  size = "size", data = df);

# %% [markdown]
# ### Doğrusal İlişkinin Cösterilmesi

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# lmplot(linear model)
sns.lmplot(x = "total_bill", y = "tip", data = df);

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "smoker", data = df);

# %%
sns.lmplot(x = "total_bill", y = "tip", hue = "smoker", col = "time", data = df );

# %%
"""
şimdi satırlara  göre  cinsiyeti okumamız gerekiyor sütünlere göre de time'i okumamız gerekiyor.
"""
sns.lmplot(x = "total_bill", y = "tip", hue = "smoker", col = "time", row = "sex", data = df);

# %% [markdown]
# ### Scatterplot Matrisi
# ##### Scatterplot :sayısal değişkenler arasındaki ilişkiyi ifade eden bir grafikti. dolayısıyle veri seti içerisindeki tüm sayısal değişkenler için matris formunda  bu ilişkiyi ifade ettiğimizde bir scatterplot matrisi oluşturmuş oluyoruz.

# %% [markdown]
# Iris veri seti, 1936'da Ronald A. Fisher tarafından tanıtılan ve üç farklı iris çiçeği türüne (Setosa, Versicolor, Virginica) ait toplam 150 örnek içeren klasik bir veri setidir. Her türden 50 örnek bulunur.
#
# Veri seti, dört özellik içerir:
#
# - Sepal Length (Çanak Yaprak Uzunluğu)
# - Sepal Width (Çanak Yaprak Genişliği)
# - Petal Length (Taç Yaprak Uzunluğu)
# - Petal Width (Taç Yaprak Genişliği)

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
df = iris.copy()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
import pandas as pd
df.species = pd.Categorical(df.species)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.species.unique()
# Out:
# ['setosa', 'versicolor', 'virginica']
# Categories (3, object): ['setosa', 'versicolor', 'virginica']

# %%
df["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
"""
*scatterplot görsellerinde yani saçılım grafiği gösellerinde eğer oluşturulmuş olan 
grafik bir tozu bulutu şekinde ise   veya yapısal bir formu yoksa  bu o iki değişken arasında
bir ilişki olmadığı anlamına  gelir.
"""
sns.pairplot(df);

# %%
sns.pairplot(df ,hue = "species");

# %%
"""
markers argümanı, farklı sınıflar için kullanılacak işaretleyici tiplerinin listesini belirtir.
Bu işaretleyiciler, Matplotlib'den alınır ve genellikle pairplot gibi fonksiyonlarda
görselleştirmenin ayrıntılarını belirlemek için kullanılır.
"o": Daire (Circle)
"s": Kare (Square)
"d": İnce Elmas (Thin Diamond)
"""
sns.pairplot(df, hue ="species", markers = ["o","s","d"]);

# %%
# kind = "reg") doğru ekleme
sns.pairplot(df, kind = "reg", hue = "species");

# %% [markdown]
# ### Heatmap

# %% [markdown]
# #### Bu veri seti, bir hava yolu şirketinin belirli bir zaman dilimindeki yolcu sayısını aylık bazda göstermektedir.

# %%
import seaborn as sns
flights = sns.load_dataset("flights")
df = flights.copy()
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.shape
# Out:
# (144, 3)

# %%
df.dtypes
# Out:
# year             int64
# month         category
# passengers       int64
# dtype: object

# %%
df.isnull().values.any()
# Out:
# False

# %%
df[['passengers']].describe().T
# Out:
#             count        mean         std    min    25%    50%    75%    max
# passengers  144.0  280.298611  119.966317  104.0  180.0  265.5  360.5  622.0

# %%
# Ayları sıralı kategori olarak ayarlayın
#df['month'] = pd.Categorical(df['month'], 
                            # categories=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], 
                             #ordered=True)

# Pivot işlemi
df = df.pivot(index='month', columns='year', values='passengers')
df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
"""
Heatmap, veri setinin ısı haritası olarak görselleştirilmesinde kullanılan bir tekniktir.
Veri setindeki her bir değeri renk tonlarıyla temsil ederek verinin yapısal
özelliklerini ve ilişkileri görsel olarak ortaya koyar. Heatmap'ler, özellikle matris 
biçimindeki veri setlerini görselleştirmek için kullanılır
"""
sns.heatmap(df);

# %%
sns.heatmap(annot = True, fmt = "d", data = df);

# %%
# bir çizgi çekeliö.
sns.heatmap(annot = True, fmt = "d",cmap="crest", linewidths = .7, data = df);

# %%
# cbar = False argümanı ile  renk barını kaldırabiliriz.
sns.heatmap(df, annot = True, fmt = "d", linewidths = .7, cbar = False);

# %% [markdown]
# ### Çizgi Grafik ve Çaprazlamalar

# %% [markdown]
# #### Veri Seti Hikayesi
# ##### fmri isimi verilen bir veri seti beyine bağlanan bir cihaz aracığıyla toplanan sinyalleri ifade eden bir veri setidir.
# - **subject**: Deneye katılan bireylerin kimlik numaralarını temsil eder.
# - **timepoint**: FMRI taramalarının zaman noktalarını (zaman adımlarını) temsil eder.
# - **event**: Deney sırasında gerçekleşen olayların türünü temsil eder. Örneğin, "stim" veya "cue" gibi.
# - **region**: Beynin hangi bölgesinin incelendiğini temsil eder. Örneğin, "parietal" veya "frontal" gibi.
# - **signal**: FMRI taramaları sırasında elde edilen sinyal değerlerini temsil eder.

# %%
import seaborn as sns
fmri = sns.load_dataset("fmri")
df = fmri.copy()
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df.dtypes
# Out:
# subject       object
# timepoint      int64
# event         object
# region        object
# signal       float64
# dtype: object

# %%
df.event = pd.Categorical(df.event)
df.subject = pd.Categorical(df.subject)
df.region = pd.Categorical(df.region)

# %%
df.dtypes
# Out:
# subject      category
# timepoint       int64
# event        category
# region       category
# signal        float64
# dtype: object

# %%
df.shape
# Out:
# (1064, 5)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df["event"].value_counts()
# Out:
# event
# cue     532
# stim    532
# Name: count, dtype: int64

# %%
df.region.unique()
# Out:
# ['parietal', 'frontal']
# Categories (2, object): ['frontal', 'parietal']

# %%
df["timepoint"].describe()
# Out:
# count    1064.000000
# mean        9.000000
# std         5.479801
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        14.000000
# max        18.000000
# Name: timepoint, dtype: float64

# %%
df["signal"].describe()
# Out:
# count    1064.000000
# mean        0.003540
# std         0.093930
# min        -0.255486
# 25%        -0.046070
# 50%        -0.013653
# 75%         0.024293
# max         0.564985
# Name: signal, dtype: float64

# %%
df.describe().T
# Out:
#             count     mean       std       min      25%       50%        75%  \
# timepoint  1064.0  9.00000  5.479801  0.000000  4.00000  9.000000  14.000000
# signal     1064.0  0.00354  0.093930 -0.255486 -0.04607 -0.013653   0.024293
#
#                  max
# timepoint  18.000000
# signal      0.564985

# %%
df.groupby("timepoint")["signal"].count()
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby("signal").count()
# Out:
#            subject  timepoint  event  region
# signal
# -0.255486        1          1      1       1
# -0.238474        1          1      1       1
# -0.224351        1          1      1       1
# -0.181241        1          1      1       1
# -0.178510        1          1      1       1
# ...            ...        ...    ...     ...
#  0.455575        1          1      1       1
#  0.460896        1          1      1       1
#  0.476055        1          1      1       1
#  0.494787        1          1      1       1
#  0.564985        1          1      1       1
#
# [1064 rows x 4 columns]

# %%
df.groupby("timepoint")["signal"].describe()
# Tarihi ve saati al
#!date /T
#!time /T
# Out:
#            count      mean       std       min       25%       50%       75%  \
# timepoint
# 0           56.0 -0.016662  0.028326 -0.064454 -0.039169 -0.018382  0.003539
# 1           56.0 -0.025002  0.030641 -0.082174 -0.046299 -0.024533 -0.005388
# 2           56.0 -0.012873  0.035440 -0.110565 -0.034944 -0.013183  0.009318
# 3           56.0  0.034446  0.058260 -0.089708 -0.001157  0.028430  0.061840
# 4           56.0  0.098194  0.092838 -0.046347  0.030912  0.070166  0.144911
# 5           56.0  0.137725  0.123353 -0.017946  0.042762  0.096535  0.211638
# 6           56.0  0.127515  0.137332 -0.054405  0.022409  0.068850  0.218919
# 7           56.0  0.075660  0.129704 -0.108222 -0.016252  0.032486  0.144781
# 8           56.0  0.013420  0.104216 -0.181241 -0.049453 -0.012834  0.030396
# 9           56.0 -0.032041  0.072728 -0.152929 -0.075693 -0.038496  0.008717
# 10          56.0 -0.053685  0.053148 -0.176453 -0.078893 -0.052906 -0.015302
# ...

# %%
"""
seaborn lib aggreged (toplulastirilmis) islemler yapar.  ve buda bize
farkinda olmadan aslinda cok daha  karmasik islemleri cok daha kolay 
bir sekilde gozleme bilmeyi saglar.
"""
sns.lineplot(x = "timepoint", y = "signal", data = df);

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "event", style = "event", data = df);

# %%
sns.lineplot(x="timepoint", 
             y="signal", 
             hue="event", 
             style="event", 
             markers=True, 
             dashes=False, 
             data=df);

# %%
sns.lineplot(x="timepoint", 
             y="signal", 
             hue="region", 
             style="event",            
             data=df);

# %% [markdown]
# ### Basit Zaman Serisi Grafiği

# %%
# anaconda içerisinde yer alamdığı için lik başta indirilir
# !pip install yfinance
# apple'in borsadaki hisse senedi değerleri olacak
import yfinance as yf

# %% [markdown]
# - **Open**: Hisse senedinin belirli bir günün başlangıcındaki fiyatı.
# - **High**: Hisse senedinin belirli bir gün içindeki en yüksek fiyatı.
# - **Low**: Hisse senedinin belirli bir gün içindeki en düşük fiyatı.
# - **Close**: Hisse senedinin belirli bir günün sonunda kapanış fiyatı.
# - **Adj Close**: Ayarlanmış kapanış fiyatı. Bu fiyat, bölünmeler ve temettü dağıtımları gibi olaylardan sonra hisse senedi fiyatının düzeltilmiş halidir.
# - **Volume**: Belirli bir gün içinde alınıp satılan hisse senedi adedi.

# %%
df = yf.download("AAPL", start="2017-01-01", end="2024-05-25")

df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2017-01-03  28.950001  29.082500  28.690001  29.037500  26.952707  115127600
# 2017-01-04  28.962500  29.127501  28.937500  29.004999  26.922541   84472400
# 2017-01-05  28.980000  29.215000  28.952499  29.152500  27.059444   88774400
# 2017-01-06  29.195000  29.540001  29.117500  29.477501  27.361113  127007600
# 2017-01-09  29.487499  29.857500  29.485001  29.747499  27.611734  134247600

# %%
df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.shape
# Out:
# (1924, 6)

# %%
df.describe().T
# Out:
#             count          mean           std           min           25%  \
# Open       1861.0  1.042890e+02  5.526160e+01  2.895000e+01  4.709500e+01
# High       1861.0  1.054202e+02  5.582812e+01  2.908250e+01  4.744500e+01
# Low        1861.0  1.032303e+02  5.472046e+01  2.869000e+01  4.669500e+01
# Close      1861.0  1.043744e+02  5.529482e+01  2.900500e+01  4.714500e+01
# Adj Close  1861.0  1.025199e+02  5.567303e+01  2.692254e+01  4.499079e+01
# Volume     1861.0  1.049616e+08  5.361613e+07  2.404830e+07  6.994080e+07
#
#                     50%           75%           max
# Open       1.145700e+02  1.537000e+02  1.980200e+02
# High       1.160000e+02  1.555000e+02  1.996200e+02
# Low        1.127800e+02  1.519200e+02  1.970000e+02
# Close      1.149500e+02  1.538400e+02  1.981100e+02
# Adj Close  1.124643e+02  1.523303e+02  1.975895e+02
# Volume     9.142000e+07  1.249253e+08  4.479400e+08

# %%
closing = df["Close"]

# %%
closing.head()
# Out:
# Date
# 2017-01-03    29.037500
# 2017-01-04    29.004999
# 2017-01-05    29.152500
# 2017-01-06    29.477501
# 2017-01-09    29.747499
# Name: Close, dtype: float64

# %%
closing.plot();

# %%
closing.index
# Out:
# DatetimeIndex(['2017-01-03', '2017-01-04', '2017-01-05', '2017-01-06',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-17',
#                ...
#                '2024-05-13', '2024-05-14', '2024-05-15', '2024-05-16',
#                '2024-05-17', '2024-05-20', '2024-05-21', '2024-05-22',
#                '2024-05-23', '2024-05-24'],
#               dtype='datetime64[ns]', name='Date', length=1861, freq=None)

# %%
#problem ile karşılaşırsak aşağıdaki yöntemi kullanırız.
closing.index =pd.DatetimeIndex(closing.index)

# %%
closing.head()
# Out:
# Date
# 2017-01-03    29.037500
# 2017-01-04    29.004999
# 2017-01-05    29.152500
# 2017-01-06    29.477501
# 2017-01-09    29.747499
# Name: Close, dtype: float64

# %%
closing.plot();

# %%
df = df.pivot(index='', columns='Close', values='Volume')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[412], line 1
# ----> 1 df = df.pivot(index='Date', columns='Close', values='Volume')
#
# ...
